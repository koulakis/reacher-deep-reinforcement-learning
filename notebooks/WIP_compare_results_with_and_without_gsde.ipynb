# %% [markdown]
# # **WIP**: Note that the following experiments have to be repeated with optimized hyperparameters, thus are not a fair benchmark for gSDE

# %%
from utils import plot_several_experiment_curves

# %% [markdown]
# ## PPO

# %%
experiments_ppo_stability = [
    ('zoo - run 1', '../experiments/zoo_ppo/tensorboard_logs/PPO_1/events.out.tfevents.1592161274.mariosk-G3-3590.3944.0'),
    ('zoo - run 2', '../experiments/zoo_ppo/tensorboard_logs/PPO_2/events.out.tfevents.1592163524.mariosk-G3-3590.5096.0'),
    ('zoo - run 3', '../experiments/zoo_ppo/tensorboard_logs/PPO_3/events.out.tfevents.1592165915.mariosk-G3-3590.8203.0'),
    
    ('zoo with gsde - run 1', '../experiments/zoo_ppo_gsde/tensorboard_logs/PPO_1/events.out.tfevents.1592288250.mariosk-G3-3590.5087.0'),
    ('zoo with gsde - run 2', '../experiments/zoo_ppo_gsde/tensorboard_logs/PPO_2/events.out.tfevents.1592290597.mariosk-G3-3590.7466.0'),
    ('zoo with gsde - run 3', '../experiments/zoo_ppo_gsde/tensorboard_logs/PPO_3/events.out.tfevents.1592292677.mariosk-G3-3590.8370.0'),
]

# %%
plot_several_experiment_curves(
    experiments_ppo_stability, 
    title='PPO',
    save_name='ppo_zoo_gsde',
    colors=3*['blue']+3*['orange'])

# %% [markdown]
# ## A2C

# %%
experiments_a2c_stability = [
    ('zoo - run 1',  '../experiments/zoo_a2c/tensorboard_logs/A2C_1/events.out.tfevents.1592250280.mariosk-G3-3590.3199.0'),
    ('zoo - run 2',  '../experiments/zoo_a2c/tensorboard_logs/A2C_2/events.out.tfevents.1592251202.mariosk-G3-3590.4969.0'),
    ('zoo - run 3',  '../experiments/zoo_a2c/tensorboard_logs/A2C_3/events.out.tfevents.1592252537.mariosk-G3-3590.9093.0'),
    
    ('zoo with gsde - run 1', '../experiments/zoo_a2c_gsde/tensorboard_logs/A2C_1/events.out.tfevents.1592288269.mariosk-G3-3590.5536.0'),
    ('zoo with gsde - run 2', '../experiments/zoo_a2c_gsde/tensorboard_logs/A2C_2/events.out.tfevents.1592289381.mariosk-G3-3590.6849.0'),
    ('zoo with gsde - run 3', '../experiments/zoo_a2c_gsde/tensorboard_logs/A2C_3/events.out.tfevents.1592290501.mariosk-G3-3590.7261.0'),
]

# %%
plot_several_experiment_curves(
    experiments_a2c_stability, 
    title='A2C',
    save_name='a2c_zoo_gsde',
    colors=3*['blue']+3*['orange'])

# %% [markdown]
# ## SAC

# %%
experiments_sac_stability = [
    ('zoo - run 1', '../experiments/zoo_sac/tensorboard_logs/SAC_1/events.out.tfevents.1592161345.mariosk-G3-3590.4558.0'),
    ('zoo - run 2', '../experiments/zoo_sac/tensorboard_logs/SAC_2/events.out.tfevents.1592166980.mariosk-G3-3590.9308.0'),
    ('zoo - run 3', '../experiments/zoo_sac/tensorboard_logs/SAC_3/events.out.tfevents.1592201949.mariosk-G3-3590.5795.0'),
    
    ('zoo with gsde- run 1', '../experiments/zoo_sac_gsde/tensorboard_logs/SAC_1/events.out.tfevents.1592292359.mariosk-G3-3590.8142.0'),
    ('zoo with gsde- run 2', '../experiments/zoo_sac_gsde/tensorboard_logs/SAC_2/events.out.tfevents.1592297767.mariosk-G3-3590.9905.0'),
    ('zoo with gsde- run 3', '../experiments/zoo_sac_gsde/tensorboard_logs/SAC_3/events.out.tfevents.1592302721.mariosk-G3-3590.11884.0'),
]

# %%
plot_several_experiment_curves(
    experiments_sac_stability, 
    title='SAC',
    save_name='sac_zoo_gsde',
    xlim=(0, 500000),
    colors=3*['orange']+3*['blue'])
